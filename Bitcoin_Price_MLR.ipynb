# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_excel('Bitcoin Data.xlsx')
df.head()
# Out:
#    SNo     Name Symbol                Date        High         Low  \
# 0    1  Bitcoin    BTC 2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC 2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC 2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC 2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC 2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)

duplicates = df.duplicated().sum()
print("\nNumber of Duplicate Rows:", duplicates)

summary = df.describe()
print("\nSummary Statistics:\n", summary)
# Out:
# Missing Values:
#  SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
#
# Number of Duplicate Rows: 0
#
# Summary Statistics:
#                 SNo                           Date          High           Low  \
# count  2991.000000                           2991   2991.000000   2991.000000
# mean   1496.000000  2017-06-02 23:59:59.000000256   6893.326038   6486.009539
# min       1.000000            2013-04-29 23:59:59     74.561096     65.526001
# 25%     748.500000            2015-05-17 11:59:59    436.179001    422.879486
# 50%    1496.000000            2017-06-02 23:59:59   2387.610107   2178.500000
# 75%    2243.500000            2019-06-20 11:59:59   8733.926948   8289.800459
# max    2991.000000            2021-07-06 23:59:59  64863.098908  62208.964366
# std     863.571653                            NaN  11642.832456  10869.032130
#
#                Open         Close        Volume     Marketcap
# count   2991.000000   2991.000000  2.991000e+03  2.991000e+03
# mean    6700.146240   6711.290443  1.090633e+10  1.208761e+11
# min       68.504997     68.431000  0.000000e+00  7.784112e+08
# 25%      430.445496    430.569489  3.036725e+07  6.305579e+09
# 50%     2269.889893   2286.409912  9.460360e+08  3.741503e+10
# 75%     8569.656494   8576.238715  1.592015e+10  1.499957e+11
# max    63523.754869  63503.457930  3.509679e+11  1.186364e+12
# std    11288.043736  11298.141921  1.888895e+10  2.109438e+11

# %%
from datetime import datetime
df['target'] = (df['High'] + df['Low'])/2
df['Date'] = pd.to_numeric(df['Date'], downcast='integer', errors='coerce')
df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  1367279999000000000  147.488007  134.000000
# 1    2  Bitcoin    BTC  1367366399000000000  146.929993  134.050003
# 2    3  Bitcoin    BTC  1367452799000000000  139.889999  107.720001
# 3    4  Bitcoin    BTC  1367539199000000000  125.599998   92.281898
# 4    5  Bitcoin    BTC  1367625599000000000  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap      target
# 0  134.444000  144.539993     0.0  1.603769e+09  140.744003
# 1  144.000000  139.000000     0.0  1.542813e+09  140.489998
# 2  139.000000  116.989998     0.0  1.298955e+09  123.805000
# 3  116.379997  105.209999     0.0  1.168517e+09  108.940948
# 4  106.250000   97.750000     0.0  1.085995e+09   93.613998

# %%
X = df[['Date', 'High', 'Low', 'Volume', 'Marketcap']].copy()
Y = df['target']

# Scale Data

for cols in X.columns:
  X[cols] = (X[cols] - np.mean(X[cols].values)) / np.std(X[cols].values)

print(X)

train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size=0.3, random_state=42)
# Out:
#           Date      High       Low    Volume  Marketcap
# 0    -1.731472 -0.579495 -0.584511 -0.577489  -0.565517
# 1    -1.730314 -0.579543 -0.584507 -0.577489  -0.565806
# 2    -1.729155 -0.580148 -0.586930 -0.577489  -0.566962
# 3    -1.727997 -0.581376 -0.588350 -0.577489  -0.567580
# 4    -1.726839 -0.582876 -0.589563 -0.577489  -0.567972
# ...        ...       ...       ...       ...        ...
# 2986  1.726839  2.323385  2.418713  1.473205   2.439800
# 2987  1.727997  2.406684  2.476871  0.713638   2.508498
# 2988  1.729155  2.495020  2.568318  0.742250   2.563664
# 2989  1.730314  2.438905  2.459476  0.837414   2.426739
# 2990  1.731472  2.417789  2.495019  0.825749   2.470374
#
# [2991 rows x 5 columns]

# %%
def gradient_descent(w, b, alpha, X, Y, y_pred):

   error = Y - y_pred
   cost = np.mean(error**2)
   absolute_cost = np.mean(abs(error))

   n = len(Y)
   deriv_w = -2 * np.dot(X.T, error) / n
   deriv_b = -2 * np.sum(error) / n

   w -= alpha * deriv_w
   b -= alpha * deriv_b

   return w, b, cost, absolute_cost


def linear_regression(X, Y, w, b, alpha, iterations):

  for i in range(iterations):
    y_pred = X.dot(w) + b

    w, b, cost, abs_cost = gradient_descent(w, b, alpha, X, Y, y_pred)
    if i % 500 == 0:
      # decay
      alpha *= 0.99
      print("Loss (MSE): ", cost)
      print("Loss (MAE): ", abs_cost, "\n")
      print("Iteration:", i, "Weights:", w, "Bias:", b)

  return w, b

# %%
# Linear Regression

weights = np.random.randn(X.shape[1]) * 0.01
bias = 0
alpha = 0.23405
iterations = 20000

weights, bias = linear_regression(train_X, train_Y, weights, bias, alpha, iterations)

# Getting predictions
y_pred = test_X.dot(weights) + bias
# Out:
# Loss (MSE):  175442690.74649465
# Loss (MAE):  6764.139545259024
#
# Iteration: 0 Weights: [3579.57756373 5425.83672277 5403.84050579 4430.30474563 5417.34071728] Bias: 3166.2937211357494
# Loss (MSE):  2.2286113166132904e+21
# Loss (MAE):  32229762152.08636
#
# Iteration: 500 Weights: [8.69086435e+09 1.09906144e+10 1.09442008e+10 1.01984808e+10
#  1.09706114e+10] Bias: 120541529.85467708
# Loss (MSE):  9.074013069256844e+25
# Loss (MAE):  6503387542669.527
#
# Iteration: 1000 Weights: [1.71911353e+12 2.17401929e+12 2.16483840e+12 2.01733059e+12
#  2.17006278e+12] Bias: 23842638192.521355
# Loss (MSE):  6.925092231943131e+21
# Loss (MAE):  56813653157.49443
#
# Iteration: 1500 Weights: [1.47194075e+10 1.86144099e+10 1.85358008e+10 1.72728039e+10
#  1.85805308e+10] Bias: 204152257.17997283
# Loss (MSE):  807071074.2004907
# Loss (MAE):  19405.557731854627
#
# Iteration: 2000 Weights: [ 4945.92119671 11211.31168513 10742.53315856  5759.28280753
#   7942.94316818] Bias: 6757.556438410883
# Loss (MSE):  2591.788008435404
# Loss (MAE):  28.024014805958444
#
# Iteration: 2500 Weights: [  18.5885614  5149.14610567 4673.52187665  -16.26397328 1431.17396368] Bias: 6689.313543643576
# Loss (MSE):  1784.455768557021
# Loss (MAE):  23.24162015012005
#
# Iteration: 3000 Weights: [  15.75095802 5279.62428703 4785.99729554  -13.99596873 1188.39232675] Bias: 6689.357690380935
# Loss (MSE):  1234.7591548366427
# Loss (MAE):  19.321653322618488
#
# Iteration: 3500 Weights: [  13.35216914 5383.29141556 4881.9211511   -12.02782359  988.91351849] Bias: 6689.397362450731
# Loss (MSE):  858.4929491336771
# Loss (MAE):  16.102822037517377
#
# Iteration: 4000 Weights: [  11.32498092 5465.93129378 4963.61580818  -10.32646935  824.64892151] Bias: 6689.432650527237
# Loss (MSE):  599.6344858224944
# Loss (MAE):  13.453544908045373
#
# Iteration: 4500 Weights: [   9.61197583 5532.02552579 5033.12343705   -8.86013548  689.08745571] Bias: 6689.463794912901
# Loss (MSE):  420.6857389544196
# Loss (MAE):  11.265694429846134
#
# Iteration: 5000 Weights: [   8.1643019  5585.05798608 5092.22333372   -7.59926672  576.975104  ] Bias: 6689.491116784739
# Loss (MSE):  296.403849475552
# Loss (MAE):  9.45448806114061
#
# Iteration: 5500 Weights: [   6.94052467 5627.74566919 5142.4548264    -6.516971    484.06211676] Bias: 6689.514972914239
# Loss (MSE):  209.70319202666548
# Loss (MAE):  7.951420193662027
#
# Iteration: 6000 Weights: [ 5.90558571e+00  5.66221426e+03  5.18514235e+03 -5.58916619e+00
#   4.06903063e+02] Bias: 6689.535726592842
# Loss (MSE):  148.95930487589757
# Loss (MAE):  6.700444071697509
#
# Iteration: 6500 Weights: [ 5.02987606e+00  5.69013210e+03  5.22142059e+03 -4.79453999e+00
#   3.42698264e+02] Bias: 6689.553729656275
# Loss (MSE):  106.22411027268168
# Loss (MAE):  5.657332203475762
#
# Iteration: 7000 Weights: [ 4.28842359e+00  5.71281266e+03  5.25225840e+03 -4.11439995e+00
#   2.89167722e+02] Bias: 6689.569312029887
# Loss (MSE):  76.03744224207855
# Loss (MAE):  4.785863225406668
#
# Iteration: 7500 Weights: [ 3.66018784e+00  5.73129323e+03  5.27848091e+03 -3.53246450e+00
#   2.44450631e+02] Bias: 6689.582776298028
# Loss (MSE):  54.63122096365442
# Loss (MAE):  4.056165216420371
#
# Iteration: 8000 Weights: [ 3.12745296e+00  5.74639552e+03  5.30078944e+03 -3.03462836e+00
#   2.07025093e+02] Bias: 6689.594395563838
# Loss (MSE):  39.39371234255967
# Loss (MAE):  3.443952185913031
#
# Iteration: 8500 Weights: [ 2.67530862e+00  5.75877240e+03  5.31977914e+03 -2.60872320e+00
#   1.75643804e+02] Bias: 6689.604413403808
# Loss (MSE):  28.507042032997667
# Loss (MAE):  2.9292477508138544
#
# Iteration: 9000 Weights: [ 2.29120805e+00  5.76894417e+03  5.33595453e+03 -2.24428650e+00
#   1.49282444e+02] Bias: 6689.613045099748
# Loss (MSE):  20.70074471329689
# Loss (MAE):  2.4957478069151935
#
# Iteration: 9500 Weights: [ 1.96459341e+00  5.77732667e+03  5.34974293e+03 -1.93234582e+00
#   1.27098133e+02] Bias: 6689.620479595843
# Loss (MSE):  15.083426318534164
# Loss (MAE):  2.130001968659665
#
# Iteration: 10000 Weights: [ 1.68657909e+00  5.78425324e+03  5.36150609e+03 -1.66522217e+00
#   1.08395944e+02] Bias: 6689.6268818134795
# Loss (MSE):  11.027268784538437
# Loss (MAE):  1.8209212230968455
#
# Iteration: 10500 Weights: [ 1.44968459e+00  5.78999183e+03  5.37155017e+03 -1.43635377e+00
#   9.26018368e+01] Bias: 6689.632395084765
# Loss (MSE):  8.088450063140487
# Loss (MAE):  1.5592444127431784
#
# Iteration: 11000 Weights: [ 1.24760978e+00  5.79475847e+03  5.38013423e+03 -1.24014005e+00
#   7.92407410e+01] Bias: 6689.637143554098
# Loss (MSE):  5.952084464963006
# Loss (MAE):  1.3373222718912454
#
# Iteration: 11500 Weights: [ 1.07504584e+00  5.79872775e+03  5.38747753e+03 -1.07180494e+00
#   6.79187674e+01] Bias: 6689.641234457376
# Loss (MSE):  4.393976122421501
# Loss (MAE):  1.148808690508326
#
# Iteration: 12000 Weights: [ 9.27516619e-01  5.80204123e+03  5.39376565e+03 -9.27277824e-01
#   5.83087464e+01] Bias: 6689.644760229067
# Loss (MSE):  3.25394891050454
# Loss (MAE):  0.9884222933569057
#
# Iteration: 12500 Weights: [ 8.01245475e-01  5.80481393e+03  5.39915573e+03 -8.03090565e-01
#   5.01384440e+01] Bias: 6689.647800414182
# Loss (MSE):  2.4171792245852073
# Loss (MAE):  0.8517451626869225
#
# Iteration: 13000 Weights: [ 6.93043570e-01  5.80713958e+03  5.40378088e+03 -6.96288820e-01
#   4.31809418e+01] Bias: 6689.650423379598
# Loss (MSE):  1.8010826677264526
# Loss (MAE):  0.735092996540698
#
# Iteration: 13500 Weights: [ 6.00216242e-01  5.80909477e+03  5.40775390e+03 -6.04355912e-01
#   3.72467696e+01] Bias: 6689.652687829941
# Loss (MSE):  1.3460696108856267
# Loss (MAE):  0.6353773496204247
#
# Iteration: 14000 Weights: [ 5.20484482e-01  5.81074223e+03  5.41117049e+03 -5.25147682e-01
#   3.21774582e+01] Bias: 6689.654644139635
# Loss (MSE):  1.0090056718973892
# Loss (MAE):  0.5500059538117114
#
# Iteration: 14500 Weights: [ 4.51919104e-01  5.81213345e+03  5.41411182e+03 -4.56836872e-01
#   2.78402468e+01] Bias: 6689.656335516063
# Loss (MSE):  0.7585700557138073
# Loss (MAE):  0.476805808368738
#
# Iteration: 15000 Weights: [ 3.92885531e-01  5.81331082e+03  5.41664685e+03 -3.97865709e-01
#   2.41237307e+01] Bias: 6689.657799010243
# Loss (MSE):  0.5719501061837862
# Loss (MAE):  0.41395011625063005
#
# Iteration: 15500 Weights: [ 3.41997476e-01  5.81430932e+03  5.41883418e+03 -3.46905554e-01
#   2.09342751e+01] Bias: 6689.659066391519
# Loss (MSE):  0.4324798097961508
# Loss (MAE):  0.35989669514947925
#
# Iteration: 16000 Weights: [ 2.98078070e-01  5.81515787e+03  5.42072365e+03 -3.02822591e-01
#   1.81930561e+01] Bias: 6689.660164902201
# Loss (MSE):  0.32794734364378925
# Loss (MAE):  0.3133468851873801
#
# Iteration: 16500 Weights: [ 2.60127212e-01  5.81588045e+03  5.42235770e+03 -2.64648674e-01
#   1.58336143e+01] Bias: 6689.661117906988
# Loss (MSE):  0.24937835166795103
# Loss (MAE):  0.2732012116257893
#
# Iteration: 17000 Weights: [ 2.27294150e-01  5.81649697e+03  5.42377248e+03 -2.31556571e-01
#   1.37998287e+01] Bias: 6689.661945450723
# Loss (MSE):  0.19015855977496623
# Loss (MAE):  0.2385301219448447
#
# Iteration: 17500 Weights: [ 1.98854414e-01  5.81702402e+03  5.42499884e+03 -2.02838950e-01
#   1.20442368e+01] Bias: 6689.66266473669
# Loss (MSE):  0.145399192874631
# Loss (MAE):  0.20854513559425567
#
# Iteration: 18000 Weights: [ 1.74190422e-01  5.81747543e+03  5.42606311e+03 -1.77890538e-01
#   1.05266384e+01] Bias: 6689.663290536241
# Loss (MSE):  0.11147664869245338
# Loss (MAE):  0.18257730623152976
#
# Iteration: 18500 Weights: [ 1.52775144e-01  5.81786278e+03  5.42698777e+03 -1.56192985e-01
#   9.21293434e+00] Bias: 6689.6638355393225
# Loss (MSE):  0.08569760783980294
# Loss (MAE):  0.16005842959691569
#
# Iteration: 19000 Weights: [ 1.34158337e-01  5.81819575e+03  5.42779208e+03 -1.37302008e-01
#   8.07415826e+00] Bias: 6689.664310654203
# Loss (MSE):  0.06605470267733746
# Loss (MAE):  0.140504763395208
#
# Iteration: 19500 Weights: [ 1.17954940e-01  5.81848250e+03  5.42849251e+03 -1.20836485e-01
#   7.08566864e+00] Bias: 6689.664725263657

# %%
from sklearn.metrics import r2_score

accuracy = r2_score(test_Y, y_pred)
print(f"R2 Score using testing data: {accuracy}")

y_pred_train = train_X.dot(weights) + bias
accuracy_train = r2_score(train_Y, y_pred_train)
print(f"R2 Score using training data: {accuracy_train}")
# Out:
# R2 Score using testing data: 0.9999999996845813
# R2 Score using training data: 0.9999999996063824
